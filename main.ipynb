# %%
api_key = "AIzaSyAMoFlKGde1Kzhbuc36yEsHei5kanKgKUI"

# %%
import requests
import pandas as pd
import numpy as np
import json

# %%
pd.set_option('display.max_rows', 500)
pd.set_option('display.max_columns', 1000)
pd.set_option('display.width', 1000)

# %%
import pandas as pd

data_restaurant = {
    "Name": [
        "Luigi's Italian", "Bamboo Garden", "Crispy Chicken Co.", "Ocean Delights", "El Taco Loco", 
        "Burger Town", "Sushi World", "Curry Palace", "French Feast", "Steak House",
        "Veggie Vibes", "Noodle Nest", "Seafood Shack", "Pizza Planet", "Deli Delights",
        "Waffle Window", "Brunch Box", "BBQ Barn", "Chocolate Castle", "Greek Grill",
        "Pho Real", "Island Aroma", "Momo House", "Kebab Kingdom", "Jazzed Up Java",
        "Butter Bakery", "Cold Comforts Ice Cream", "Hotpot Haven", "Ramen Realm", "Donut Den",
        "Pasta Port", "Middle Eastern Morsels", "Bread and Beyond", "Churro Chamber", "Salad Sanctuary",
        "Paella Palace", "Vegan Venture", "Tex-Mex Territory", "Bao Bun Boutique", "Crepes & Cones",
        "Mediterranean Magic", "Bagel Basket", "Tandoori Tower", "Soulfood Station", "Poutine Place",
        "Dim Sum Dome", "German Gastronomy", "Lil' Tapas", "Aussie Eats", "Czech Check","Luigi's Italian",
         "Bamboo Chinese", "Taco House", "Sushi World", "India Palace", "Thai Express", "Paris Bakery", "Olive Mediterranean", "Tex Grill", "Beijing Duck",
         "El Matador", "Casa de Tapas", "Madrid Bistro", "Iberia Eatery", "Seville's", "Barcelona Grill", "Fiesta Cantina", "Taco Loco", "Mesa Bonita", "Cielo Azul",
         "Taco Haven", "Urban Taco Hub", "Taco District", "Sunrise Tacos", "Taco Vista", "El Taco Tower", "Taco Temptations", "Taco Trail", "Twilight Taco", "Taco Treasures",
         "La Petite Bistro", 
        "Bavarian Haus", 
        "Trattoria Amore", 
        "Café du Soleil", 
        "Athena's Taverna", 
        "Nordic Delights", 
        "Tapas Temptations", 
        "Amsterdam Eatery", 
        "Budapest Bites", 
        "Oslo Oven",
        "Sushi Samba", 
        "Maki House", 
        "Nigiri Nirvana", 
        "Rolls & Bowls", 
        "Ocean Bites", 
        "Samurai Sushi", 
        "Dragon Roll Deli", 
        "Seaweed Central", 
        "Sakura Sushi Lounge", 
        "Tuna Town"
         ],
    "Cuisine": [
        "Italian", "Chinese", "American", "Seafood", "Mexican", 
        "American", "Japanese", "Indian", "French", "American",
        "Vegetarian", "Chinese", "Seafood", "Italian", "Deli",
        "Breakfast", "Breakfast", "American", "Dessert", "Greek",
        "Vietnamese", "Caribbean", "Nepali", "Middle Eastern", "Cafe",
        "Bakery", "Dessert", "Chinese", "Japanese", "Dessert",
        "Italian", "Middle Eastern", "Bakery", "Mexican", "Vegetarian",
        "Spanish", "Vegan", "Tex-Mex", "Chinese", "French",
        "Mediterranean", "Deli", "Indian", "Southern", "Canadian",
        "Chinese", "German", "Spanish", "Australian", "Czech", 'Italian', 'Chinese', 'Mexican', 'Japanese', 'Indian', 'Thai', 'French', 'Mediterranean', 'Tex-Mex', 'Chinese',
                'Spanish', 'Spanish', 'Spanish', 'Spanish', 'Spanish', 'Spanish', 'Mexican', 'Mexican', 'Mexican', 'Mexican',
                'Mexican', 'Mexican', 'Mexican', 'Mexican', 'Mexican', 'Mexican', 'Mexican', 'Mexican', 'Mexican', 'Mexican',
                'French', 
        'German', 
        'Italian', 
        'French', 
        'Greek', 
        'Scandinavian', 
        'Spanish', 
        'Dutch', 
        'Hungarian', 
        'Norwegian',
         'Japanese', 
        'Japanese', 
        'Japanese', 
        'Japanese', 
        'Japanese', 
        'Japanese', 
        'Japanese', 
        'Japanese', 
        'Japanese', 
        'Japanese'
    ]
}

df_restaurant = pd.DataFrame(data_restaurant)

print(df_restaurant)
# Out:
#                        Name         Cuisine
# 0           Luigi's Italian         Italian
# 1             Bamboo Garden         Chinese
# 2        Crispy Chicken Co.        American
# 3            Ocean Delights         Seafood
# 4              El Taco Loco         Mexican
# 5               Burger Town        American
# 6               Sushi World        Japanese
# 7              Curry Palace          Indian
# 8              French Feast          French
# 9               Steak House        American
# 10             Veggie Vibes      Vegetarian
# 11              Noodle Nest         Chinese
# 12            Seafood Shack         Seafood
# 13             Pizza Planet         Italian
# 14            Deli Delights            Deli
# 15            Waffle Window       Breakfast
# 16               Brunch Box       Breakfast
# 17                 BBQ Barn        American
# 18         Chocolate Castle         Dessert
# 19              Greek Grill           Greek
# ...

# %%
import pandas as pd
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score

X_train, X_test, y_train, y_test = train_test_split(df_restaurant['Name'], df_restaurant['Cuisine'], test_size=0.2, random_state=42)

# Using CountVectorizer to transform the restaurant names into a matrix of token counts
vectorizer = CountVectorizer()
X_train_vec = vectorizer.fit_transform(X_train)
X_test_vec = vectorizer.transform(X_test)

# Train a RandomForest Classifier
clf = RandomForestClassifier(n_estimators=100, random_state=42)
clf.fit(X_train_vec, y_train)

# Predict and evaluate on the test set
y_pred = clf.predict(X_test_vec)
accuracy = accuracy_score(y_test, y_pred)
print(f"Accuracy: {accuracy*100:.2f}%")

# Predicting cuisine for a new restaurant
new_restaurant = "Oriental Bamboo"
new_vec = vectorizer.transform([new_restaurant])
predicted_cuisine = clf.predict(new_vec)
print(f"The predicted cuisine for {new_restaurant} is {predicted_cuisine[0]}.")
# Out:
# Accuracy: 27.78%
# The predicted cuisine for Oriental Bamboo is Chinese.

# %%
def convert_time_format(time):
    

    cleaned_entry = time.replace('\u2009', ' ').replace('\u202f', ' ').strip()

    return cleaned_entry

# %%
pd.set_option('display.max_rows', 500)
pd.set_option('display.max_columns', 500)
pd.set_option('display.width', 1000)
API_KEY = 'AIzaSyAMoFlKGde1Kzhbuc36yEsHei5kanKgKUI'

# Define the endpoint URL for Nearby Search request
ENDPOINT_NEARBY = 'https://maps.googleapis.com/maps/api/place/nearbysearch/json?'

# Define the endpoint URL for Place Details request
ENDPOINT_DETAILS = 'https://maps.googleapis.com/maps/api/place/details/json?'

# Define the parameters for the nearby search
PARAMETERS_NEARBY = {
    'location': '39.768403,-86.158068',  # Indianapolis coordinates
    'radius': 50000,  # 50km radius
    'keyword': 'food truck',
    'key': API_KEY
}

# Make the API request for nearby search
response_nearby = requests.get(ENDPOINT_NEARBY, params=PARAMETERS_NEARBY)

# Convert the response to JSON
results_nearby = response_nearby.json().get('results')

# Extract relevant information from results
data = []
coordinates = []
for place in results_nearby:
    place_id = place['place_id']

    # Fetching detailed information for each place using the Place Details request
    PARAMETERS_DETAILS = {
        'place_id': place_id,
        'key': API_KEY
    }
    response_details = requests.get(ENDPOINT_DETAILS, params=PARAMETERS_DETAILS)
    results_details = response_details.json().get('result')
    lat = place['geometry']['location']['lat']
    lng = place['geometry']['location']['lng']
    coordinates.append([lat, lng])
    name = results_details['name']
    address = results_details.get('formatted_address')
    rating = results_details.get('rating')
    website = results_details.get('website')
    if website == "":
        website = "None"
    hours = results_details.get('opening_hours', {}).get('weekday_text', [])[5:7]
    weekend_hours = [hour.split(': ')[1] for hour in hours]
    weekend_hours = [convert_time_format(hour) for hour in weekend_hours]
    if hours:
         weekend_hours = [convert_time_format(hour.split(': ')[1]) if ': ' in hour else 'Closed' for hour in hours]
    else:
        weekend_hours = ['Closed', 'Closed'] 
    print(weekend_hours)
    # Assuming 'types' attribute might contain cuisine information
    cuisine = clf.predict(vectorizer.transform([name]))[0]

    data.append([name, address, rating, website, weekend_hours, cuisine])

# Convert the list to a DataFrame
df = pd.DataFrame(data, columns=['Name', 'Address', 'Rating', 'Website', 'Hours', 'Cuisine'])
df.to_csv('food_trucks.csv')
print(df.head(5))
# Out:
# ['Closed', 'Closed']
# ['5:00 – 11:00 PM', '5:00 – 11:00 PM']
# ['5:00 PM – 4:00 AM', '5:00 PM – 1:00 AM']
# ['Closed', 'Closed']
# ['Closed', 'Closed']
# ['11:00 AM – 11:00 PM', '11:00 AM – 10:00 PM']
# ['11:00 AM – 8:30 PM', 'Closed']
# ['Closed', 'Closed']
# ['2:00 – 9:30 PM', '2:00 – 9:30 PM']
# ['5:00 PM – 12:00 AM', 'Closed']
# ['10:30 AM – 1:00 AM', '10:30 AM – 12:00 AM']
# ['6:00 – 11:00 PM', 'Closed']
# ['1:59 PM – 4:59 AM', '1:59 PM – 4:59 AM']
# ['2:30 PM – 4:00 AM', '2:30 PM – 12:00 AM']
# ['3:00 PM – 12:00 AM', 'Closed']
# ['6:00 PM – 1:00 AM', '6:00 PM – 12:00 AM']
# ['Closed', 'Closed']
# ['Closed', 'Closed']
# ['11:00 AM – 10:00 PM', '12:00 – 8:00 PM']
# ['8:00 – 11:30 PM', 'Closed']
#                             Name                                            Address  Rating                                  Website                                   Hours  Cuisine
# ...

# %%
gmaps = googlemaps.Client(key=api_key)
# For each place, get the directions and details
current_location = (39.7684, -86.1581)
itinerary = []
modes = ["walking", "driving", "bicycling", "transit"]
for place in results_nearby:
    place_id = place['place_id']
    best_time = float('inf')
    best_directions = None
    best_mode = None
    PARAMETERS_DETAILS = {
        'place_id': place_id,
        'key': API_KEY
    }
    response_details = requests.get(ENDPOINT_DETAILS, params=PARAMETERS_DETAILS)
    results_details = response_details.json().get('result')

    for mode in modes:
        directions = gmaps.directions(origin=current_location, destination=place["geometry"]["location"], mode=mode)

        # Check if directions are available
        if not directions or not directions[0].get("legs"):
            continue

        current_time = directions[0]["legs"][0]["duration"]["value"]
        if current_time < best_time:
            best_time = current_time
            best_directions = directions
            best_mode = mode

    # Ensure that we have the best directions before proceeding
    if not best_directions:
        continue
    
    hours = results_details.get('opening_hours', {}).get('weekday_text', [])[5:7]

    if hours:
        weekend_hours = [convert_time_format(hour.split(': ')[1]) if ': ' in hour else 'Closed' for hour in hours]
    else:
        weekend_hours = ['Closed', 'Closed']

    print(weekend_hours)
    name = place["name"]
    address = place["vicinity"]
    travel_time = best_directions[0]["legs"][0]["duration"]["text"]
    travel_distance = best_directions[0]["legs"][0]["distance"]["text"]
    transportation_type = "Walk" if "walk" in travel_time.lower() else "Car"

    cuisine = clf.predict(vectorizer.transform([name]))[0]
    
    itinerary.append((weekend_hours, name, address, cuisine, travel_distance, travel_time, transportation_type))
# Out:
# ['Closed', 'Closed']
# ['5:00 – 11:00 PM', '5:00 – 11:00 PM']
# ['5:00 PM – 4:00 AM', '5:00 PM – 1:00 AM']
# ['Closed', 'Closed']
# ['Closed', 'Closed']
# ['11:00 AM – 11:00 PM', '11:00 AM – 10:00 PM']
# ['11:00 AM – 8:30 PM', 'Closed']
# ['Closed', 'Closed']
# ['2:00 – 9:30 PM', '2:00 – 9:30 PM']
# ['5:00 PM – 12:00 AM', 'Closed']
# ['10:30 AM – 1:00 AM', '10:30 AM – 12:00 AM']
# ['6:00 – 11:00 PM', 'Closed']
# ['1:59 PM – 4:59 AM', '1:59 PM – 4:59 AM']
# ['2:30 PM – 4:00 AM', '2:30 PM – 12:00 AM']
# ['3:00 PM – 12:00 AM', 'Closed']
# ['6:00 PM – 1:00 AM', '6:00 PM – 12:00 AM']
# ['Closed', 'Closed']
# ['Closed', 'Closed']
# ['11:00 AM – 10:00 PM', '12:00 – 8:00 PM']
# ['8:00 – 11:30 PM', 'Closed']

# %%
df2 = pd.DataFrame(itinerary, columns=["Opening Time", "Name", "Address", "Cuisine", "Distance", "Time", "Transportation"])
df2.to_csv('food_trucks_itinerary.csv')
df2
# Out:
#                                   Opening Time                              Name                                            Address   Cuisine Distance     Time Transportation
# 0                             [Closed, Closed]     Mi Lindo Pénjamo - Food Truck                     7910 Michigan Rd, Indianapolis   Spanish  10.2 mi  22 mins            Car
# 1           [5:00 – 11:00 PM, 5:00 – 11:00 PM]          los compadres food truck                   2001 S Scatterfield Rd, Anderson   Spanish  45.0 mi  52 mins            Car
# 2       [5:00 PM – 4:00 AM, 5:00 PM – 1:00 AM]          Pico de Gallo Food Truck              3014 Lafayette Rd #3000, Indianapolis   Spanish   5.6 mi  16 mins            Car
# 3                             [Closed, Closed]             Food truck Mil Amores                    5034 E Raymond St, Indianapolis   Spanish   6.3 mi  18 mins            Car
# ...

# %%
import googlemaps
import requests

# Replace with your own Google Maps API key

# Initialize the Google Maps client
gmaps = googlemaps.Client(key=api_key)

# Define the start and end coordinates (latitude and longitude)
end_location = (39.8975427, -86.2164478)  

# Request directions from Google Maps API
directions = gmaps.directions(current_location, end_location, mode="driving")

# Extract the polyline from the response
polyline = directions[0]['overview_polyline']['points']

# Generate the URL for the static map image
map_url = f"https://maps.googleapis.com/maps/api/staticmap?size=600x400&path=enc:{polyline}&key={api_key}"

# Download the map image
response = requests.get(map_url)

if response.status_code == 200:
    # Save the image to a file
    with open("directions_map.png", "wb") as f:
        f.write(response.content)
    print("Image saved as 'directions_map.png'")
else:
    print("Failed to retrieve the map image")
# Out:
# Image saved as 'directions_map.png'

# %%
import folium
import polyline
m = folium.Map(location=[39.768403,-86.158068], zoom_start=10)

# Add a marker for your location
folium.Marker(
    [39.768403,-86.158068], 
    popup='<strong>I am here</strong>', 
    icon=folium.Icon(color='red')
).add_to(m)
for idx, coord in enumerate(coordinates):
    folium.Marker([coord[0], coord[1]], popup= f'<strong>{df.Name[idx]}</strong>', tooltip=df.Name[idx],
    icon= folium.Icon(color="blue", icon_color="white", prefix="fa", icon="utensils")).add_to(m)
# Out:
# 0 40.0970805 -85.6531607
# 1 39.8099204 -86.2212091
# 2 39.7386158 -86.0821965
# 3 39.6427315 -86.12018
# 4 39.8264053 -86.00684059999999
# 5 40.1175882 -85.7068675
# 6 39.8975427 -86.2164478
# 7 39.77254509999999 -86.04034999999999
# 8 39.8527225 -86.24143649999999
# 9 39.8557077 -86.1137069
# 10 39.6981336 -86.18572879999999
# 11 39.8029754 -86.0136536
# 12 39.7608462 -86.0812326
# 13 39.8099076 -86.2216177
# 14 39.8183177 -86.22698319999999
# 15 39.827233 -86.04525
# 16 39.7882877 -86.2153062
# 17 39.6135838 -86.1095321
# 18 39.8229185 -86.2344232
# 19 39.6631666 -86.1259341

# %%
folium.PolyLine(coordinates, color="blue", dash_array="5").add_to(m)

# %%
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
# ...
